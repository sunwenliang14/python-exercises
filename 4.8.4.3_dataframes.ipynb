# %%
from pydataset import data

# %%
import pandas as pd
import numpy as np
np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#     name  math  english  reading
# 0  Sally    62       85       80
# 1   Jane    88       79       67
# 2  Suzie    94       74       95
# 3  Billy    98       96       88
# 4    Ada    77       92       98

# %%
df.shape
# Out:
# (12, 4)

# %%
df['passing_english'] = df.english >= 70
df.head()
# Out:
#     name  math  english  reading  passing_english
# 0  Sally    62       85       80             True
# 1   Jane    88       79       67             True
# 2  Suzie    94       74       95             True
# 3  Billy    98       96       88             True
# 4    Ada    77       92       98             True

# %%
df.sort_values(by = 'passing_english')
# Out:
#        name  math  english  reading  passing_english
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True

# %%
df.sort_values(by = ['passing_english', 'name'])
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %%
df.sort_values(by = ['passing_english', 'english'])
# Out:
#        name  math  english  reading  passing_english
# 1      Jane    88       79       67            False
# 8    Albert    92       62       87             True
# 11     Alan    92       62       72             True
# 7     Marie    93       63       90             True
# 6    Thomas    82       64       81             True
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %%
df['overall_grade'] = ((df.math+df.english+df.reading)/3).astype(int)
df
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 0     Sally    62       85       80             True             75
# 1      Jane    88       79       67             True             78
# 2     Suzie    94       74       95             True             87
# 3     Billy    98       96       88             True             94
# 4       Ada    77       92       98             True             89
# 5      John    79       76       93             True             82
# 6    Thomas    82       64       81            False             75
# 7     Marie    93       63       90            False             82
# 8    Albert    92       62       87            False             80
# 9   Richard    69       80       94             True             81
# 10    Isaac    92       99       93             True             94
# 11     Alan    92       62       72            False             75

# %%
mpg = data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
# How many rows and columns are there? 234 rows × 11 columns

# %%
mpg.shape
# Out:
# (234, 13)

# %%
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 13 columns):
# manufacturer          234 non-null object
# model                 234 non-null object
# displ                 234 non-null float64
# year                  234 non-null int64
# cyl                   234 non-null int64
# trans                 234 non-null object
# drv                   234 non-null object
# cty                   234 non-null int64
# hwy                   234 non-null int64
# fl                    234 non-null object
# class                 234 non-null object
# mileage_difference    234 non-null int64
# average_mileage       234 non-null float64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 25.6+ KB

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy  \
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000
#
#        mileage_difference  average_mileage
# count          234.000000       234.000000
# mean             6.581197        20.149573
# std              2.262739         5.050290
# min              2.000000        10.500000
# 25%              5.000000        15.500000
# 50%              7.000000        20.500000
# 75%              8.000000        23.500000
# ...

# %%
mpg.rename(columns={'cty':'city'})
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ...

# %%
mpg.rename(columns={'hwy':'highway'})
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %%
mpg[mpg.cty > mpg.hwy]
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, cty, hwy, fl, class, mileage_difference, average_mileage]
# Index: []

# %%
mpg['mileage_difference'] = mpg.hwy - mpg.cty
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference
# 1    compact                  11
# 2    compact                   8
# ...

# %%
mpg.sort_values(by ='mileage_difference').tail(2)
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  cty  hwy fl  \
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f   29   41  d
# 107        honda       civic    1.8  2008    4  auto(l5)   f   24   36  c
#
#           class  mileage_difference  average_mileage
# 223  subcompact                  12             35.0
# 107  subcompact                  12             30.0

# %%
mpg.mileage_difference.max()
filt = mpg.mileage_difference == mpg.mileage_difference.max()
filt
mpg[filt]
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  cty  hwy fl  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f   24   36  c
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f   29   41  d
#
#           class  mileage_difference  average_mileage
# 107  subcompact                  12             30.0
# 223  subcompact                  12             35.0

# %%
mpg['class'].value_counts()
filt = mpg['class'] == 'compact'
filt
# Out:
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
#        ...
# 230    False
# 231    False
# 232    False
# 233    False
# 234    False
# Name: class, Length: 234, dtype: bool

# %%
mpg[filt]
mpg[filt].sort_values(by='hwy')
# Out:
#     manufacturer         model  displ  year  cyl       trans drv  cty  hwy fl  \
# 220   volkswagen         jetta    2.8  1999    6    auto(l4)   f   16   23  r
# 221   volkswagen         jetta    2.8  1999    6  manual(m5)   f   17   24  r
# 212   volkswagen           gti    2.8  1999    6  manual(m5)   f   17   24  r
# 172       subaru   impreza awd    2.5  2008    4  manual(m5)   4   19   25  p
# 170       subaru   impreza awd    2.5  2008    4    auto(s4)   4   20   25  p
# 15          audi    a4 quattro    3.1  2008    6  manual(m6)   4   15   25  p
# 14          audi    a4 quattro    3.1  2008    6    auto(s6)   4   17   25  p
# 13          audi    a4 quattro    2.8  1999    6  manual(m5)   4   17   25  p
# 9           audi    a4 quattro    1.8  1999    4    auto(l5)   4   16   25  p
# 12          audi    a4 quattro    2.8  1999    6    auto(l5)   4   15   25  p
# 209   volkswagen           gti    2.0  1999    4    auto(l4)   f   19   26  r
# ...

# %%
mpg[filt].sort_values(by='hwy').head(1)
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  cty  hwy fl    class  \
# 220   volkswagen  jetta    2.8  1999    6  auto(l4)   f   16   23  r  compact
#
#      mileage_difference  average_mileage
# 220                   7             19.5

# %%
mpg[filt].sort_values(by='hwy').tail(1)
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  cty  hwy fl  \
# 213   volkswagen  jetta    1.9  1999    4  manual(m5)   f   33   44  d
#
#        class  mileage_difference  average_mileage
# 213  compact                  11             38.5

# %%
mpg['average_mileage'] = (mpg.cty + mpg.hwy)/2
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference  average_mileage
# 1    compact                  11             23.5
# ...

# %%
mpg[mpg.manufacturer.str.contains('dodge')].sort_values(by='average_mileage').head(4)
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  cty  \
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
# 66        dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 60        dodge          durango 4wd    4.7  2008    8    auto(l5)   4    9
# 55        dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
#
#     hwy fl   class  mileage_difference  average_mileage
# 70   12  e  pickup                   3             10.5
# 66   12  e  pickup                   3             10.5
# 60   12  e     suv                   3             10.5
# 55   12  e  pickup                   3             10.5

# %%
mpg[mpg.manufacturer.str.contains('dodge')].sort_values(by='average_mileage').tail(1)
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  cty  hwy fl  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f   18   24  r
#
#       class  mileage_difference  average_mileage
# 38  minivan                   6             21.0

# %%
Mammals = data('Mammals')
Mammals.head()
# Out:
#    weight  speed  hoppers  specials
# 1  6000.0   35.0    False     False
# 2  4000.0   26.0    False     False
# 3  3000.0   25.0    False     False
# 4  1400.0   45.0    False     False
# 5   400.0   70.0    False     False

# %%
Mammals.shape
# Out:
# (107, 4)

# %%
Mammals.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %%
Mammals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
# weight      107 non-null float64
# speed       107 non-null float64
# hoppers     107 non-null bool
# specials    107 non-null bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
Mammals.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %%
Mammals.speed.max()
Mammals[Mammals.speed == Mammals.speed.max()]
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False

# %%
Mammals.specials.sum()/Mammals.specials.count()
# Out:
# 0.09345794392523364

# %%
Mammals.speed.median()
# Out:
# 48.0

# %%
hoppers = Mammals[Mammals.hoppers == True]
hoppers
# Out:
#      weight  speed  hoppers  specials
# 82    0.056   21.0     True     False
# 85    0.035   32.0     True     False
# 86    0.035   14.0     True     False
# 96    4.600   64.0     True     False
# 97    4.400   72.0     True     False
# 98    4.000   72.0     True     False
# 99    3.500   56.0     True     False
# 100   2.000   64.0     True     False
# 101   1.900   56.0     True     False
# 102   1.500   50.0     True     False
# 103   1.500   40.0     True     False

# %%
faster_hoppers = hoppers.speed > Mammals.speed.median()
faster_hoppers
# Out:
# 82     False
# 85     False
# 86     False
# 96      True
# 97      True
# 98      True
# 99      True
# 100     True
# 101     True
# 102     True
# 103    False
# Name: speed, dtype: bool

# %%
hoppers[faster_hoppers]
# Out:
#      weight  speed  hoppers  specials
# 96      4.6   64.0     True     False
# 97      4.4   72.0     True     False
# 98      4.0   72.0     True     False
# 99      3.5   56.0     True     False
# 100     2.0   64.0     True     False
# 101     1.9   56.0     True     False
# 102     1.5   50.0     True     False

# %%
len(hoppers[faster_hoppers])/len(hoppers)
# Out:
# 0.6363636363636364
